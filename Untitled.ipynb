# %%
import logging
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from utils import Sample, SampleDataset, ensure_dir

# --- basic logger setup (prints to stdout) ---
logger = logging.getLogger("plot_scribbles")
if not logger.handlers:
    handler = logging.StreamHandler()
    fmt = logging.Formatter("[%(levelname)s] %(message)s")
    handler.setFormatter(fmt)
    logger.addHandler(handler)
logger.setLevel(logging.INFO)


def _save(fig, out_path: Path):
    """Save figure with tight bbox and minimal padding."""
    fig.tight_layout()
    fig.savefig(out_path, dpi=fig.dpi, bbox_inches="tight", pad_inches=0.02)
    plt.close(fig)


def plot_sample_comparisons(sample: Sample, out_dir: Path, dpi: int = 300, logger: logging.Logger = logger):
    """
    For one Sample, conditionally generate figures ONLY if the corresponding manual scribble exists.
    - Figure A: DAPI vs nucleus scribble (requires nuc_scribble)
    - Figure B: (Marker + DAPI) vs cell scribble (requires cell_chan AND marker_scribble)

    Returns a dict of {"figure_name": saved_path} for figures actually written.
    """
    sample.load_images()
    sample.load_scribbles()
    ensure_dir(out_dir)
    saved = {}

    # ---------- A) DAPI vs nucleus scribble ----------
    if sample.nuc_scribble is None:
        logger.info(f"[{sample.base}] skip DAPI-vs-nuc: no nuc_scribble")
    else:
        if sample.nuc_chan is None:
            logger.info(f"[{sample.base}] skip DAPI-vs-nuc: no nuc_chan (DAPI image missing)")
        elif sample.nuc_scribble.shape != sample.nuc_chan.shape:
            logger.warning(f"[{sample.base}] skip DAPI-vs-nuc: shape mismatch scribble {sample.nuc_scribble.shape} vs dapi {sample.nuc_chan.shape}")
        else:
            fig, axs = plt.subplots(1, 2, figsize=(12, 6), dpi=dpi)
            axs[0].imshow(sample.nuc_chan, cmap="gray")
            axs[0].set_title("DAPI channel")
            axs[0].axis("off")

            axs[1].imshow(sample.nuc_chan, cmap="gray")
            axs[1].imshow(sample.nuc_scribble, cmap="jet", alpha=0.5)
            axs[1].set_title("Nucleus scribble overlay")
            axs[1].axis("off")

            out_path = out_dir / f"{sample.base}_dapi_vs_nuc.png"
            _save(fig, out_path)
            saved["dapi_vs_nuc"] = str(out_path)
            logger.info(f"[{sample.base}] saved {out_path.name}")

    # ---------- B) (Marker + DAPI) vs cell scribble ----------
    need = []
    if sample.cell_chan is None:
        need.append("marker channel")
    if sample.marker_scribble is None:
        need.append("cell scribble")
    if need:
        logger.info(f"[{sample.base}] skip marker+dapi-vs-cell: missing {', '.join(need)}")
    else:
        # Check shapes
        if sample.cell_chan.shape != sample.nuc_chan.shape:
            logger.warning(f"[{sample.base}] skip marker+dapi-vs-cell: channel shape mismatch marker {sample.cell_chan.shape} vs dapi {sample.nuc_chan.shape}")
        elif sample.marker_scribble.shape != sample.cell_chan.shape:
            logger.warning(f"[{sample.base}] skip marker+dapi-vs-cell: scribble {sample.marker_scribble.shape} vs channels {sample.cell_chan.shape}")
        else:
            # Compose RGB: Marker -> R, DAPI -> B
            rgb = np.zeros((*sample.cell_chan.shape, 3), dtype=np.float32)
            rgb[..., 0] = sample.cell_chan  # red = marker
            rgb[..., 2] = sample.nuc_chan   # blue = dapi

            fig, axs = plt.subplots(1, 2, figsize=(12, 6), dpi=dpi)
            axs[0].imshow(rgb)
            axs[0].set_title("Marker + DAPI composite")
            axs[0].axis("off")

            axs[1].imshow(rgb)
            axs[1].imshow(sample.marker_scribble, cmap="jet", alpha=0.5)
            axs[1].set_title("Cell scribble overlay")
            axs[1].axis("off")

            out_path = out_dir / f"{sample.base}_marker_dapi_vs_cell.png"
            _save(fig, out_path)
            saved["marker_dapi_vs_cell"] = str(out_path)
            logger.info(f"[{sample.base}] saved {out_path.name}")

    return saved


def batch_plot(data_dir: Path, out_dir: Path, dpi: int = 300):
    """
    Iterate all samples and generate figures when eligible.
    Prints a compact summary at the end.
    """
    ds = SampleDataset(Path(data_dir))
    ensure_dir(out_dir)

    total_samples = 0
    total_figs = 0
    for sample in ds:
        total_samples += 1
        saved = plot_sample_comparisons(sample, out_dir, dpi=dpi, logger=logger)
        total_figs += len(saved)

    logger.info(f"Done. {total_figs} figures written from {total_samples} samples.")


# Example usage:
# batch_plot(Path("your_data_dir"), Path("plots"), dpi=400)

# %%
batch_plot(Path("00_dataset"), Path("plots"), dpi=80)
# Out:
# [INFO] [gfap_3527] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_3527] saved gfap_3527_marker_dapi_vs_cell.png
# [INFO] [gfap_3532] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_3532] saved gfap_3532_marker_dapi_vs_cell.png
# [INFO] [gfap_3569] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_3569] saved gfap_3569_marker_dapi_vs_cell.png
# [INFO] [gfap_3999] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_3999] saved gfap_3999_marker_dapi_vs_cell.png
# [INFO] [gfap_4201] saved gfap_4201_dapi_vs_nuc.png
# [INFO] [gfap_4201] saved gfap_4201_marker_dapi_vs_cell.png
# [INFO] [gfap_4238] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_4238] saved gfap_4238_marker_dapi_vs_cell.png
# [INFO] [gfap_4319] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_4319] saved gfap_4319_marker_dapi_vs_cell.png
# [INFO] [gfap_4515] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_4515] saved gfap_4515_marker_dapi_vs_cell.png
# [INFO] [gfap_4548] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_4548] saved gfap_4548_marker_dapi_vs_cell.png
# [INFO] [gfap_4642] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_4642] saved gfap_4642_marker_dapi_vs_cell.png
# [INFO] [gfap_4683] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_4683] saved gfap_4683_marker_dapi_vs_cell.png
# [INFO] [gfap_4736] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_4736] saved gfap_4736_marker_dapi_vs_cell.png
# [INFO] [gfap_5059] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_5059] saved gfap_5059_marker_dapi_vs_cell.png
# [INFO] [gfap_5191] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_5191] saved gfap_5191_marker_dapi_vs_cell.png
# [INFO] [gfap_5410] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_5410] saved gfap_5410_marker_dapi_vs_cell.png
# [INFO] [gfap_5789] saved gfap_5789_dapi_vs_nuc.png
# [INFO] [gfap_5789] saved gfap_5789_marker_dapi_vs_cell.png
# [INFO] [gfap_5792] saved gfap_5792_dapi_vs_nuc.png
# [INFO] [gfap_5792] saved gfap_5792_marker_dapi_vs_cell.png
# [INFO] [gfap_5794] saved gfap_5794_dapi_vs_nuc.png
# [INFO] [gfap_5794] saved gfap_5794_marker_dapi_vs_cell.png
# [INFO] [gfap_5795] saved gfap_5795_dapi_vs_nuc.png
# [INFO] [gfap_5795] saved gfap_5795_marker_dapi_vs_cell.png
# [INFO] [gfap_5803] saved gfap_5803_dapi_vs_nuc.png
# [INFO] [gfap_5803] saved gfap_5803_marker_dapi_vs_cell.png
# [INFO] [gfap_5863] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_5863] saved gfap_5863_marker_dapi_vs_cell.png
# [INFO] [gfap_5923] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_5923] saved gfap_5923_marker_dapi_vs_cell.png
# [INFO] [gfap_6020] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_6020] saved gfap_6020_marker_dapi_vs_cell.png
# [INFO] [gfap_6212] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_6212] saved gfap_6212_marker_dapi_vs_cell.png
# [INFO] [gfap_6390] saved gfap_6390_dapi_vs_nuc.png
# [INFO] [gfap_6390] saved gfap_6390_marker_dapi_vs_cell.png
# [INFO] [gfap_6466] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_6466] saved gfap_6466_marker_dapi_vs_cell.png
# [INFO] [gfap_6523] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_6523] saved gfap_6523_marker_dapi_vs_cell.png
# [INFO] [gfap_6748] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_6748] saved gfap_6748_marker_dapi_vs_cell.png
# [INFO] [gfap_6790] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_6790] saved gfap_6790_marker_dapi_vs_cell.png
# [INFO] [gfap_6833] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [gfap_6833] saved gfap_6833_marker_dapi_vs_cell.png
# [INFO] [iba1_10015] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_10015] saved iba1_10015_marker_dapi_vs_cell.png
# [INFO] [iba1_10061] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_10061] saved iba1_10061_marker_dapi_vs_cell.png
# [INFO] [iba1_10166] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_10166] saved iba1_10166_marker_dapi_vs_cell.png
# [INFO] [iba1_7071] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_7071] saved iba1_7071_marker_dapi_vs_cell.png
# [INFO] [iba1_7113] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_7113] saved iba1_7113_marker_dapi_vs_cell.png
# [INFO] [iba1_7319] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_7319] saved iba1_7319_marker_dapi_vs_cell.png
# [INFO] [iba1_7685] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_7685] saved iba1_7685_marker_dapi_vs_cell.png
# [INFO] [iba1_7739] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_7739] saved iba1_7739_marker_dapi_vs_cell.png
# [INFO] [iba1_7870] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_7870] saved iba1_7870_marker_dapi_vs_cell.png
# [INFO] [iba1_7925] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_7925] saved iba1_7925_marker_dapi_vs_cell.png
# [INFO] [iba1_7962] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_7962] saved iba1_7962_marker_dapi_vs_cell.png
# [INFO] [iba1_8224] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_8224] saved iba1_8224_marker_dapi_vs_cell.png
# [INFO] [iba1_8265] saved iba1_8265_dapi_vs_nuc.png
# [INFO] [iba1_8265] saved iba1_8265_marker_dapi_vs_cell.png
# [INFO] [iba1_8310] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_8310] saved iba1_8310_marker_dapi_vs_cell.png
# [INFO] [iba1_8405] saved iba1_8405_dapi_vs_nuc.png
# [INFO] [iba1_8405] saved iba1_8405_marker_dapi_vs_cell.png
# [INFO] [iba1_8406] saved iba1_8406_dapi_vs_nuc.png
# [INFO] [iba1_8406] saved iba1_8406_marker_dapi_vs_cell.png
# [INFO] [iba1_8407] saved iba1_8407_dapi_vs_nuc.png
# [INFO] [iba1_8407] saved iba1_8407_marker_dapi_vs_cell.png
# [INFO] [iba1_8408] saved iba1_8408_dapi_vs_nuc.png
# [INFO] [iba1_8408] saved iba1_8408_marker_dapi_vs_cell.png
# [INFO] [iba1_8409] saved iba1_8409_dapi_vs_nuc.png
# [INFO] [iba1_8409] saved iba1_8409_marker_dapi_vs_cell.png
# [INFO] [iba1_8517] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_8517] saved iba1_8517_marker_dapi_vs_cell.png
# [INFO] [iba1_8550] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_8550] saved iba1_8550_marker_dapi_vs_cell.png
# [INFO] [iba1_8746] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_8746] saved iba1_8746_marker_dapi_vs_cell.png
# [INFO] [iba1_8917] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_8917] saved iba1_8917_marker_dapi_vs_cell.png
# [INFO] [iba1_8942] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_8942] saved iba1_8942_marker_dapi_vs_cell.png
# [INFO] [iba1_9106] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_9106] saved iba1_9106_marker_dapi_vs_cell.png
# [INFO] [iba1_9170] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_9170] saved iba1_9170_marker_dapi_vs_cell.png
# [INFO] [iba1_9472] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_9472] saved iba1_9472_marker_dapi_vs_cell.png
# [INFO] [iba1_9755] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_9755] saved iba1_9755_marker_dapi_vs_cell.png
# [INFO] [iba1_9783] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_9783] saved iba1_9783_marker_dapi_vs_cell.png
# [INFO] [iba1_9866] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [iba1_9866] saved iba1_9866_marker_dapi_vs_cell.png
# [INFO] [neun_1108] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1108] saved neun_1108_marker_dapi_vs_cell.png
# [INFO] [neun_1109] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1109] saved neun_1109_marker_dapi_vs_cell.png
# [INFO] [neun_1110] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1110] saved neun_1110_marker_dapi_vs_cell.png
# [INFO] [neun_1111] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1111] saved neun_1111_marker_dapi_vs_cell.png
# [INFO] [neun_1112] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1112] saved neun_1112_marker_dapi_vs_cell.png
# [INFO] [neun_1113] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1113] saved neun_1113_marker_dapi_vs_cell.png
# [INFO] [neun_1114] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1114] saved neun_1114_marker_dapi_vs_cell.png
# [INFO] [neun_1115] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1115] saved neun_1115_marker_dapi_vs_cell.png
# [INFO] [neun_1116] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1116] saved neun_1116_marker_dapi_vs_cell.png
# [INFO] [neun_1120] saved neun_1120_dapi_vs_nuc.png
# [INFO] [neun_1120] saved neun_1120_marker_dapi_vs_cell.png
# [INFO] [neun_1360] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1360] saved neun_1360_marker_dapi_vs_cell.png
# [INFO] [neun_1492] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1492] saved neun_1492_marker_dapi_vs_cell.png
# [INFO] [neun_1534] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_1534] saved neun_1534_marker_dapi_vs_cell.png
# [INFO] [neun_2144] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_2144] saved neun_2144_marker_dapi_vs_cell.png
# [INFO] [neun_2232] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_2232] saved neun_2232_marker_dapi_vs_cell.png
# [INFO] [neun_2529] saved neun_2529_dapi_vs_nuc.png
# [INFO] [neun_2529] saved neun_2529_marker_dapi_vs_cell.png
# [INFO] [neun_2783] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_2783] saved neun_2783_marker_dapi_vs_cell.png
# [INFO] [neun_2822] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_2822] saved neun_2822_marker_dapi_vs_cell.png
# [INFO] [neun_3067] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_3067] saved neun_3067_marker_dapi_vs_cell.png
# [INFO] [neun_307] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_307] saved neun_307_marker_dapi_vs_cell.png
# [INFO] [neun_3392] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_3392] saved neun_3392_marker_dapi_vs_cell.png
# [INFO] [neun_355] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_355] saved neun_355_marker_dapi_vs_cell.png
# [INFO] [neun_400] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_400] saved neun_400_marker_dapi_vs_cell.png
# [INFO] [neun_568] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_568] saved neun_568_marker_dapi_vs_cell.png
# [INFO] [neun_585] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_585] saved neun_585_marker_dapi_vs_cell.png
# [INFO] [neun_635] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_635] saved neun_635_marker_dapi_vs_cell.png
# [INFO] [neun_679] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_679] saved neun_679_marker_dapi_vs_cell.png
# [INFO] [neun_728] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_728] saved neun_728_marker_dapi_vs_cell.png
# [INFO] [neun_806] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_806] saved neun_806_marker_dapi_vs_cell.png
# [INFO] [neun_888] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [neun_888] saved neun_888_marker_dapi_vs_cell.png
# [INFO] [olig2_10396] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_10396] saved olig2_10396_marker_dapi_vs_cell.png
# [INFO] [olig2_10594] saved olig2_10594_dapi_vs_nuc.png
# [INFO] [olig2_10594] saved olig2_10594_marker_dapi_vs_cell.png
# [INFO] [olig2_11036] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_11036] saved olig2_11036_marker_dapi_vs_cell.png
# [INFO] [olig2_11126] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_11126] saved olig2_11126_marker_dapi_vs_cell.png
# [INFO] [olig2_12105] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_12105] saved olig2_12105_marker_dapi_vs_cell.png
# [INFO] [olig2_12358] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_12358] saved olig2_12358_marker_dapi_vs_cell.png
# [INFO] [olig2_12400] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_12400] saved olig2_12400_marker_dapi_vs_cell.png
# [INFO] [olig2_12445] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_12445] saved olig2_12445_marker_dapi_vs_cell.png
# [INFO] [olig2_12779] saved olig2_12779_dapi_vs_nuc.png
# [INFO] [olig2_12779] saved olig2_12779_marker_dapi_vs_cell.png
# [INFO] [olig2_12780] saved olig2_12780_dapi_vs_nuc.png
# [INFO] [olig2_12780] saved olig2_12780_marker_dapi_vs_cell.png
# [INFO] [olig2_12781] saved olig2_12781_dapi_vs_nuc.png
# [INFO] [olig2_12781] saved olig2_12781_marker_dapi_vs_cell.png
# [INFO] [olig2_12782] saved olig2_12782_dapi_vs_nuc.png
# [INFO] [olig2_12782] saved olig2_12782_marker_dapi_vs_cell.png
# [INFO] [olig2_12783] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_12783] saved olig2_12783_marker_dapi_vs_cell.png
# [INFO] [olig2_12784] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_12784] saved olig2_12784_marker_dapi_vs_cell.png
# [INFO] [olig2_12785] saved olig2_12785_dapi_vs_nuc.png
# [INFO] [olig2_12785] saved olig2_12785_marker_dapi_vs_cell.png
# [INFO] [olig2_12786] saved olig2_12786_dapi_vs_nuc.png
# [INFO] [olig2_12786] saved olig2_12786_marker_dapi_vs_cell.png
# [INFO] [olig2_12787] saved olig2_12787_dapi_vs_nuc.png
# [INFO] [olig2_12787] saved olig2_12787_marker_dapi_vs_cell.png
# [INFO] [olig2_12788] saved olig2_12788_dapi_vs_nuc.png
# [INFO] [olig2_12788] saved olig2_12788_marker_dapi_vs_cell.png
# [INFO] [olig2_12789] saved olig2_12789_dapi_vs_nuc.png
# [INFO] [olig2_12789] saved olig2_12789_marker_dapi_vs_cell.png
# [INFO] [olig2_12790] saved olig2_12790_dapi_vs_nuc.png
# [INFO] [olig2_12790] saved olig2_12790_marker_dapi_vs_cell.png
# [INFO] [olig2_12791] saved olig2_12791_dapi_vs_nuc.png
# [INFO] [olig2_12791] saved olig2_12791_marker_dapi_vs_cell.png
# [INFO] [olig2_12792] saved olig2_12792_dapi_vs_nuc.png
# [INFO] [olig2_12792] saved olig2_12792_marker_dapi_vs_cell.png
# [INFO] [olig2_12793] saved olig2_12793_dapi_vs_nuc.png
# [INFO] [olig2_12793] saved olig2_12793_marker_dapi_vs_cell.png
# [INFO] [olig2_12794] saved olig2_12794_dapi_vs_nuc.png
# [INFO] [olig2_12794] saved olig2_12794_marker_dapi_vs_cell.png
# [INFO] [olig2_12795] saved olig2_12795_dapi_vs_nuc.png
# [INFO] [olig2_12795] saved olig2_12795_marker_dapi_vs_cell.png
# [INFO] [olig2_12796] saved olig2_12796_dapi_vs_nuc.png
# [INFO] [olig2_12796] saved olig2_12796_marker_dapi_vs_cell.png
# [INFO] [olig2_12797] saved olig2_12797_dapi_vs_nuc.png
# [INFO] [olig2_12797] saved olig2_12797_marker_dapi_vs_cell.png
# [INFO] [olig2_12798] saved olig2_12798_dapi_vs_nuc.png
# [INFO] [olig2_12798] saved olig2_12798_marker_dapi_vs_cell.png
# [INFO] [olig2_12799] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_12799] saved olig2_12799_marker_dapi_vs_cell.png
# [INFO] [olig2_13161] skip DAPI-vs-nuc: no nuc_scribble
# [INFO] [olig2_13161] saved olig2_13161_marker_dapi_vs_cell.png
# [INFO] [pecam_15591] saved pecam_15591_dapi_vs_nuc.png
# [INFO] [pecam_15591] saved pecam_15591_marker_dapi_vs_cell.png
# [INFO] [pecam_15968] saved pecam_15968_dapi_vs_nuc.png
# [INFO] [pecam_15968] saved pecam_15968_marker_dapi_vs_cell.png
# [INFO] [pecam_15969] saved pecam_15969_dapi_vs_nuc.png
# [INFO] [pecam_15969] saved pecam_15969_marker_dapi_vs_cell.png
# [INFO] [pecam_15970] saved pecam_15970_dapi_vs_nuc.png
# [INFO] [pecam_15970] saved pecam_15970_marker_dapi_vs_cell.png
# [INFO] [pecam_15971] saved pecam_15971_dapi_vs_nuc.png
# [INFO] [pecam_15971] saved pecam_15971_marker_dapi_vs_cell.png
# [INFO] [pecam_15972] saved pecam_15972_dapi_vs_nuc.png
# [INFO] [pecam_15972] saved pecam_15972_marker_dapi_vs_cell.png
# [INFO] [pecam_15973] saved pecam_15973_dapi_vs_nuc.png
# [INFO] [pecam_15973] saved pecam_15973_marker_dapi_vs_cell.png
# [INFO] Done. 168 figures written from 127 samples.

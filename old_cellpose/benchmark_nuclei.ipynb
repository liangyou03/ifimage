# %%
import importlib
import ifimage_tools
importlib.reload(ifimage_tools)
import pandas as pd
import warnings
import pickle

# %%
import os
import numpy as np
from stardist.matching import matching
image_dir = "/home/liy121/ifimage/Reorgnized Ground Truth"
dataset = ifimage_tools.IfImageDataset(image_dir, masks_dir, {})
dataset.load_data()
old_version_sample_ids = ["6390", "8408", "8406", "8405v2", "8405", "8407"]
for sample_id in old_version_sample_ids:
    if sample_id in dataset.samples:
        del dataset.samples[sample_id]

# %%
output_root = "mask"
os.makedirs(output_root, exist_ok=True)

for sample_id, sample in dataset.samples.items():
    # 跑 nucleus segmentation pipeline
    sample.apply_nuc_pipeline()
    
    # 给每个 sample 创建自己的子文件夹：mask/<sample_id>/
    sample_dir = os.path.join(output_root, sample_id)
    os.makedirs(sample_dir, exist_ok=True)
    
    # 遍历 sample.masks，把不为空的 mask 存成 .npy
    for mask_name, mask_array in sample.masks.items():
        if mask_array is None:
            continue
        out_path = os.path.join(sample_dir, f"{mask_name}.npy")
        np.save(out_path, mask_array)
        print(f"Saved {mask_name} → {out_path}")
# Out:
# Saved cyto → mask/5803/cyto.npy
# Saved cyto2 → mask/5803/cyto2.npy
# Saved watershed → mask/5803/watershed.npy
# Saved cyto → mask/12781/cyto.npy
# Saved cyto2 → mask/12781/cyto2.npy
# Saved watershed → mask/12781/watershed.npy
# Saved cyto → mask/12779/cyto.npy
# Saved cyto2 → mask/12779/cyto2.npy
# Saved watershed → mask/12779/watershed.npy
# Saved cyto → mask/12786/cyto.npy
# Saved cyto2 → mask/12786/cyto2.npy
# Saved watershed → mask/12786/watershed.npy
# Saved cyto → mask/10594/cyto.npy
# Saved cyto2 → mask/10594/cyto2.npy
# Saved watershed → mask/10594/watershed.npy
# Saved cyto → mask/8408jan22/cyto.npy
# Saved cyto2 → mask/8408jan22/cyto2.npy
# Saved watershed → mask/8408jan22/watershed.npy
# Saved cyto → mask/15591/cyto.npy
# Saved cyto2 → mask/15591/cyto2.npy
# Saved watershed → mask/15591/watershed.npy
# Saved cyto → mask/12793/cyto.npy
# Saved cyto2 → mask/12793/cyto2.npy
# Saved watershed → mask/12793/watershed.npy
# Saved cyto → mask/15972/cyto.npy
# Saved cyto2 → mask/15972/cyto2.npy
# Saved watershed → mask/15972/watershed.npy
# Saved cyto → mask/12794/cyto.npy
# Saved cyto2 → mask/12794/cyto2.npy
# Saved watershed → mask/12794/watershed.npy
# Saved cyto → mask/1120/cyto.npy
# Saved cyto2 → mask/1120/cyto2.npy
# Saved watershed → mask/1120/watershed.npy
# Saved cyto → mask/12795/cyto.npy
# Saved cyto2 → mask/12795/cyto2.npy
# Saved watershed → mask/12795/watershed.npy
# Saved cyto → mask/12792/cyto.npy
# Saved cyto2 → mask/12792/cyto2.npy
# Saved watershed → mask/12792/watershed.npy
# Saved cyto → mask/12787/cyto.npy
# Saved cyto2 → mask/12787/cyto2.npy
# Saved watershed → mask/12787/watershed.npy
# Saved cyto → mask/12780/cyto.npy
# Saved cyto2 → mask/12780/cyto2.npy
# Saved watershed → mask/12780/watershed.npy
# Saved cyto → mask/2529/cyto.npy
# Saved cyto2 → mask/2529/cyto2.npy
# Saved watershed → mask/2529/watershed.npy
# Saved cyto → mask/8265/cyto.npy
# Saved cyto2 → mask/8265/cyto2.npy
# Saved watershed → mask/8265/watershed.npy
# Saved cyto → mask/15973/cyto.npy
# Saved cyto2 → mask/15973/cyto2.npy
# Saved watershed → mask/15973/watershed.npy
# Saved cyto → mask/12798/cyto.npy
# Saved cyto2 → mask/12798/cyto2.npy
# Saved watershed → mask/12798/watershed.npy
# Saved cyto → mask/8407jan22/cyto.npy
# Saved cyto2 → mask/8407jan22/cyto2.npy
# Saved watershed → mask/8407jan22/watershed.npy
# Saved cyto → mask/8406jan22/cyto.npy
# Saved cyto2 → mask/8406jan22/cyto2.npy
# Saved watershed → mask/8406jan22/watershed.npy
# Saved cyto → mask/12799/cyto.npy
# Saved cyto2 → mask/12799/cyto2.npy
# Saved watershed → mask/12799/watershed.npy
# Saved cyto → mask/8405jan22/cyto.npy
# Saved cyto2 → mask/8405jan22/cyto2.npy
# Saved watershed → mask/8405jan22/watershed.npy
# Saved cyto → mask/15970/cyto.npy
# Saved cyto2 → mask/15970/cyto2.npy
# Saved watershed → mask/15970/watershed.npy
# Saved cyto → mask/12791/cyto.npy
# Saved cyto2 → mask/12791/cyto2.npy
# Saved watershed → mask/12791/watershed.npy
# Saved cyto → mask/12784/cyto.npy
# Saved cyto2 → mask/12784/cyto2.npy
# Saved watershed → mask/12784/watershed.npy
# Saved cyto → mask/15968/cyto.npy
# Saved cyto2 → mask/15968/cyto2.npy
# Saved watershed → mask/15968/watershed.npy
# Saved cyto → mask/12789/cyto.npy
# Saved cyto2 → mask/12789/cyto2.npy
# Saved watershed → mask/12789/watershed.npy
# Saved cyto → mask/12783/cyto.npy
# Saved cyto2 → mask/12783/cyto2.npy
# Saved watershed → mask/12783/watershed.npy
# Saved cyto → mask/12796/cyto.npy
# Saved cyto2 → mask/12796/cyto2.npy
# Saved watershed → mask/12796/watershed.npy
# Saved cyto → mask/15969/cyto.npy
# Saved cyto2 → mask/15969/cyto2.npy
# Saved watershed → mask/15969/watershed.npy
# Saved cyto → mask/12797/cyto.npy
# Saved cyto2 → mask/12797/cyto2.npy
# Saved watershed → mask/12797/watershed.npy
# Saved cyto → mask/12782/cyto.npy
# Saved cyto2 → mask/12782/cyto2.npy
# Saved watershed → mask/12782/watershed.npy
# Saved cyto → mask/15971/cyto.npy
# Saved cyto2 → mask/15971/cyto2.npy
# Saved watershed → mask/15971/watershed.npy
# Saved cyto → mask/12785/cyto.npy
# Saved cyto2 → mask/12785/cyto2.npy
# Saved watershed → mask/12785/watershed.npy
# Saved cyto → mask/12790/cyto.npy
# Saved cyto2 → mask/12790/cyto2.npy
# Saved watershed → mask/12790/watershed.npy
# Saved cyto → mask/12788/cyto.npy
# Saved cyto2 → mask/12788/cyto2.npy
# Saved watershed → mask/12788/watershed.npy
# Saved cyto → mask/8409/cyto.npy
# Saved cyto2 → mask/8409/cyto2.npy
# Saved watershed → mask/8409/watershed.npy
# Saved cyto → mask/6390v2/cyto.npy
# Saved cyto2 → mask/6390v2/cyto2.npy
# Saved watershed → mask/6390v2/watershed.npy
# Saved cyto → mask/8550/cyto.npy
# Saved cyto2 → mask/8550/cyto2.npy
# Saved watershed → mask/8550/watershed.npy
# Saved cyto → mask/8917/cyto.npy
# Saved cyto2 → mask/8917/cyto2.npy
# Saved watershed → mask/8917/watershed.npy
# Saved cyto → mask/5191/cyto.npy
# Saved cyto2 → mask/5191/cyto2.npy
# Saved watershed → mask/5191/watershed.npy
# Saved cyto → mask/6833/cyto.npy
# Saved cyto2 → mask/6833/cyto2.npy
# Saved watershed → mask/6833/watershed.npy
# Saved cyto → mask/10166/cyto.npy
# Saved cyto2 → mask/10166/cyto2.npy
# Saved watershed → mask/10166/watershed.npy
# Saved cyto → mask/9106/cyto.npy
# Saved cyto2 → mask/9106/cyto2.npy
# Saved watershed → mask/9106/watershed.npy
# Saved cyto → mask/4642/cyto.npy
# Saved cyto2 → mask/4642/cyto2.npy
# Saved watershed → mask/4642/watershed.npy
# Saved cyto → mask/5792/cyto.npy
# Saved cyto2 → mask/5792/cyto2.npy
# Saved watershed → mask/5792/watershed.npy
# Saved cyto → mask/10061/cyto.npy
# Saved cyto2 → mask/10061/cyto2.npy
# Saved watershed → mask/10061/watershed.npy
# Saved cyto → mask/1110/cyto.npy
# Saved cyto2 → mask/1110/cyto2.npy
# Saved watershed → mask/1110/watershed.npy
# Saved cyto → mask/7925/cyto.npy
# Saved cyto2 → mask/7925/cyto2.npy
# Saved watershed → mask/7925/watershed.npy
# Saved cyto → mask/5863/cyto.npy
# Saved cyto2 → mask/5863/cyto2.npy
# Saved watershed → mask/5863/watershed.npy
# Saved cyto → mask/1112/cyto.npy
# Saved cyto2 → mask/1112/cyto2.npy
# Saved watershed → mask/1112/watershed.npy
# Saved cyto → mask/7739/cyto.npy
# Saved cyto2 → mask/7739/cyto2.npy
# Saved watershed → mask/7739/watershed.npy
# Saved cyto → mask/5059/cyto.npy
# Saved cyto2 → mask/5059/cyto2.npy
# Saved watershed → mask/5059/watershed.npy
# Saved cyto → mask/7113/cyto.npy
# Saved cyto2 → mask/7113/cyto2.npy
# Saved watershed → mask/7113/watershed.npy
# Saved cyto → mask/3569/cyto.npy
# Saved cyto2 → mask/3569/cyto2.npy
# Saved watershed → mask/3569/watershed.npy
# Saved cyto → mask/7685/cyto.npy
# Saved cyto2 → mask/7685/cyto2.npy
# Saved watershed → mask/7685/watershed.npy
# Saved cyto → mask/8224/cyto.npy
# Saved cyto2 → mask/8224/cyto2.npy
# Saved watershed → mask/8224/watershed.npy
# Saved cyto → mask/4515/cyto.npy
# Saved cyto2 → mask/4515/cyto2.npy
# Saved watershed → mask/4515/watershed.npy
# Saved cyto → mask/7870/cyto.npy
# Saved cyto2 → mask/7870/cyto2.npy
# Saved watershed → mask/7870/watershed.npy
# Saved cyto → mask/6790/cyto.npy
# Saved cyto2 → mask/6790/cyto2.npy
# Saved watershed → mask/6790/watershed.npy
# Saved cyto → mask/7962/cyto.npy
# Saved cyto2 → mask/7962/cyto2.npy
# Saved watershed → mask/7962/watershed.npy
# Saved cyto → mask/1111/cyto.npy
# Saved cyto2 → mask/1111/cyto2.npy
# Saved watershed → mask/1111/watershed.npy
# Saved cyto → mask/8746/cyto.npy
# Saved cyto2 → mask/8746/cyto2.npy
# Saved watershed → mask/8746/watershed.npy
# Saved cyto → mask/3532/cyto.npy
# Saved cyto2 → mask/3532/cyto2.npy
# Saved watershed → mask/3532/watershed.npy
# Saved cyto → mask/3999/cyto.npy
# Saved cyto2 → mask/3999/cyto2.npy
# Saved watershed → mask/3999/watershed.npy
# Saved cyto → mask/3527/cyto.npy
# Saved cyto2 → mask/3527/cyto2.npy
# Saved watershed → mask/3527/watershed.npy
# Saved cyto → mask/7071/cyto.npy
# Saved cyto2 → mask/7071/cyto2.npy
# Saved watershed → mask/7071/watershed.npy
# Saved cyto → mask/5923/cyto.npy
# Saved cyto2 → mask/5923/cyto2.npy
# Saved watershed → mask/5923/watershed.npy
# Saved cyto → mask/5789/cyto.npy
# Saved cyto2 → mask/5789/cyto2.npy
# Saved watershed → mask/5789/watershed.npy
# Saved cyto → mask/5794/cyto.npy
# Saved cyto2 → mask/5794/cyto2.npy
# Saved watershed → mask/5794/watershed.npy
# Saved cyto → mask/9755/cyto.npy
# Saved cyto2 → mask/9755/cyto2.npy
# Saved watershed → mask/9755/watershed.npy
# Saved cyto → mask/6020/cyto.npy
# Saved cyto2 → mask/6020/cyto2.npy
# Saved watershed → mask/6020/watershed.npy
# Saved cyto → mask/9170/cyto.npy
# Saved cyto2 → mask/9170/cyto2.npy
# Saved watershed → mask/9170/watershed.npy
# Saved cyto → mask/10015/cyto.npy
# Saved cyto2 → mask/10015/cyto2.npy
# Saved watershed → mask/10015/watershed.npy
# Saved cyto → mask/1116/cyto.npy
# Saved cyto2 → mask/1116/cyto2.npy
# Saved watershed → mask/1116/watershed.npy
# Saved cyto → mask/4238/cyto.npy
# Saved cyto2 → mask/4238/cyto2.npy
# Saved watershed → mask/4238/watershed.npy
# Saved cyto → mask/1114/cyto.npy
# Saved cyto2 → mask/1114/cyto2.npy
# Saved watershed → mask/1114/watershed.npy
# Saved cyto → mask/5795/cyto.npy
# Saved cyto2 → mask/5795/cyto2.npy
# Saved watershed → mask/5795/watershed.npy
# Saved cyto → mask/4548/cyto.npy
# Saved cyto2 → mask/4548/cyto2.npy
# Saved watershed → mask/4548/watershed.npy
# Saved cyto → mask/8517/cyto.npy
# Saved cyto2 → mask/8517/cyto2.npy
# Saved watershed → mask/8517/watershed.npy
# Saved cyto → mask/9783/cyto.npy
# Saved cyto2 → mask/9783/cyto2.npy
# Saved watershed → mask/9783/watershed.npy
# Saved cyto → mask/1108/cyto.npy
# Saved cyto2 → mask/1108/cyto2.npy
# Saved watershed → mask/1108/watershed.npy
# Saved cyto → mask/8310/cyto.npy
# Saved cyto2 → mask/8310/cyto2.npy
# Saved watershed → mask/8310/watershed.npy
# Saved cyto → mask/9472/cyto.npy
# Saved cyto2 → mask/9472/cyto2.npy
# Saved watershed → mask/9472/watershed.npy
